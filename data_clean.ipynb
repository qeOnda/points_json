# %% [markdown]
# #Project name

# %% [markdown]
# #1. Stop and Search Data
# ##1.1 Download stop and search data and combine into single file
# The data comes from:
# For the purpose of this project, we downloaded stop and search for the year 2019 -- Jan, 1 to Dec, 31.
# The source files were monthly reports - we combine them below.

# %%
import pandas as pd
import geopandas as gpd
from geopandas import GeoDataFrame as gdf
import glob 
import json
import numpy as np
import os

# %%
files = glob.glob("/Users/sean/desktop/proj_london/data/source_data/*.csv")
appended = [pd.read_csv(f) for f in files]
combined = pd.concat(appended, ignore_index=True)
combined.to_csv(r'/Users/sean/desktop/proj_london/data/combined_stop_data.csv')

# %% [markdown]
# ##1.2 Read combined stop and search data
# Read combined data csv and check data:

# %%
df = pd.read_csv('combined_stop_data.csv', dtype={"Latitude": str, "Longitude": str})
df.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268469 entries, 0 to 268468
# Data columns (total 16 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Unnamed: 0                                268469 non-null  int64
#  1   Type                                      268469 non-null  object
#  2   Date                                      268469 non-null  object
#  3   Part of a policing operation              265940 non-null  float64
#  4   Policing operation                        0 non-null       float64
#  5   Latitude                                  241403 non-null  object
#  6   Longitude                                 241403 non-null  object
#  7   Gender                                    264904 non-null  object
#  8   Age range                                 239826 non-null  object
#  9   Self-defined ethnicity                    264774 non-null  object
#  10  Officer-defined ethnicity                 262970 non-null  object
#  11  Legislation                               268468 non-null  object
#  12  Object of search                          267733 non-null  object
#  13  Outcome                                   268461 non-null  object
#  14  Outcome linked to object of search        2528 non-null    object
#  15  Removal of more than just outer clothing  2528 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 32.8+ MB

# %% [markdown]
# ##1.3 Clean dataframe
# Change column names and drop irrelevant columns:

# %%
df.rename(columns=
         {'Self-defined ethnicity': 'ethnicity',
         'Officer-defined ethnicity':'officer_ethnicity',
         'Object of search': 'purpose',
         'Part of a policing operation': 'operation',
         'Age range': 'age_range',
         'Gender': 'gender',
         'Outcome': 'outcome',
         'Legislation': 'legislation',
         'Date': 'date',
          'Latitude': 'latitude',
          'Longitude': 'longitude',
          'Type': 'type'
         },
         inplace=True)
df.columns
# Out:
# Index(['Unnamed: 0', 'type', 'date', 'operation', 'Policing operation',
#        'latitude', 'longitude', 'gender', 'age_range', 'ethnicity',
#        'officer_ethnicity', 'legislation', 'purpose', 'outcome',
#        'Outcome linked to object of search',
#        'Removal of more than just outer clothing'],
#       dtype='object')

# %%
df = df.drop(['Policing operation', 'Outcome linked to object of search', 'Removal of more than just outer clothing'], axis = 1)

# %%
df_cleaned = df.dropna(axis=0)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 212165 entries, 0 to 268315
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         212165 non-null  int64
#  1   type               212165 non-null  object
#  2   date               212165 non-null  object
#  3   operation          212165 non-null  float64
#  4   latitude           212165 non-null  object
#  5   longitude          212165 non-null  object
#  6   gender             212165 non-null  object
#  7   age_range          212165 non-null  object
#  8   ethnicity          212165 non-null  object
#  9   officer_ethnicity  212165 non-null  object
#  10  legislation        212165 non-null  object
#  11  purpose            212165 non-null  object
#  12  outcome            212165 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 22.7+ MB

# %% [markdown]
# ##1.4 Add coordinate column
# Combine lat and long to create coordinate column for easy referencing

# %%
df_cleaned['coord'] = "(" + df_cleaned.latitude + ", " + df_cleaned.longitude + ")"
# Out:
# <ipython-input-75-0f464366702c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['coord'] = "(" + df_cleaned.latitude + ", " + df_cleaned.longitude + ")"

# %%
df_cleaned.head()
# Out:
#    Unnamed: 0                       type                       date  \
# 0           0  Person and Vehicle search  2019-07-31T23:00:00+00:00
# 1           1  Person and Vehicle search  2019-07-31T23:02:00+00:00
# 4           4              Person search  2019-07-31T23:05:00+00:00
# 5           5              Person search  2019-07-31T23:05:00+00:00
# 8           8              Person search  2019-07-31T23:07:00+00:00
#
#    operation            latitude  longitude gender age_range  \
# 0        0.0           51.460887   0.005072   Male     25-34
# 1        0.0  51.480146999999995  -0.507249   Male     25-34
# 4        0.0           51.486675  -0.093976   Male     25-34
# 5        0.0           51.509962  -0.131179   Male     10-17
# 8        0.0           51.509962  -0.131179   Male     18-24
#
#                                            ethnicity officer_ethnicity  \
# 0  White - English/Welsh/Scottish/Northern Irish/...             White
# 1  Black/African/Caribbean/Black British - Any ot...             Black
# 4   Asian/Asian British - Any other Asian background             Asian
# 5                    Other ethnic group - Not stated             White
# 8  Black/African/Caribbean/Black British - Caribbean             Asian
#
#                              legislation           purpose  \
# 0  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
# 1  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
# 4  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
# 5  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
# 8  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
#
#                         outcome                            coord
# 0  A no further action disposal            (51.460887, 0.005072)
# 1                        Arrest  (51.480146999999995, -0.507249)
# 4  A no further action disposal           (51.486675, -0.093976)
# 5          Community resolution           (51.509962, -0.131179)
# 8          Community resolution           (51.509962, -0.131179)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 212165 entries, 0 to 268315
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         212165 non-null  int64
#  1   type               212165 non-null  object
#  2   date               212165 non-null  object
#  3   operation          212165 non-null  float64
#  4   latitude           212165 non-null  object
#  5   longitude          212165 non-null  object
#  6   gender             212165 non-null  object
#  7   age_range          212165 non-null  object
#  8   ethnicity          212165 non-null  object
#  9   officer_ethnicity  212165 non-null  object
#  10  legislation        212165 non-null  object
#  11  purpose            212165 non-null  object
#  12  outcome            212165 non-null  object
#  13  coord              212165 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 24.3+ MB

# %% [markdown]
# ##1.5.1 Clean up ethnicity column
# There are many overlapping sub-categories. Group ethnicity together to eliminate said overlap.

# %%
df_cleaned['ethnicity'].value_counts()
# Out:
# White - English/Welsh/Scottish/Northern Irish/British                                   41346
# Other ethnic group - Not stated                                                         34068
# Black/African/Caribbean/Black British - Any other Black/African/Caribbean background    28721
# White - Any other White background                                                      27215
# Black/African/Caribbean/Black British - African                                         20187
# Asian/Asian British - Any other Asian background                                        14911
# Black/African/Caribbean/Black British - Caribbean                                       13425
# Asian/Asian British - Bangladeshi                                                        9329
# Other ethnic group - Any other ethnic group                                              5797
# Asian/Asian British - Pakistani                                                          4033
# Mixed/Multiple ethnic groups - Any other Mixed/Multiple ethnic background                3865
# Asian/Asian British - Indian                                                             3474
# Mixed/Multiple ethnic groups - White and Black Caribbean                                 2348
# White - Irish                                                                            1856
# Mixed/Multiple ethnic groups - White and Black African                                    784
# Mixed/Multiple ethnic groups - White and Asian                                            468
# Asian/Asian British - Chinese                                                             338
# Name: ethnicity, dtype: int64

# %%
def func(x):
    if 'White' in x:
        return 'White'
    elif 'Black' in x:
        return 'Black'
    elif 'Asian' in x:
        return 'Asian'
    elif 'Mixed' in x:
        return 'Mixed group'
    elif 'Not stated' in x:
        return 'Not stated'
    else:
        return 'Other'

# %%
df_cleaned['ethnicity_simple'] = df_cleaned['ethnicity'].apply(func)
# Out:
# <ipython-input-80-a36d89105834>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['ethnicity_simple'] = df_cleaned['ethnicity'].apply(func)

# %%
df_cleaned.head()
# Out:
#    Unnamed: 0                       type                       date  \
# 0           0  Person and Vehicle search  2019-07-31T23:00:00+00:00
# 1           1  Person and Vehicle search  2019-07-31T23:02:00+00:00
# 4           4              Person search  2019-07-31T23:05:00+00:00
# 5           5              Person search  2019-07-31T23:05:00+00:00
# 8           8              Person search  2019-07-31T23:07:00+00:00
#
#    operation            latitude  longitude gender age_range  \
# 0        0.0           51.460887   0.005072   Male     25-34
# 1        0.0  51.480146999999995  -0.507249   Male     25-34
# 4        0.0           51.486675  -0.093976   Male     25-34
# 5        0.0           51.509962  -0.131179   Male     10-17
# 8        0.0           51.509962  -0.131179   Male     18-24
#
#                                            ethnicity officer_ethnicity  \
# 0  White - English/Welsh/Scottish/Northern Irish/...             White
# 1  Black/African/Caribbean/Black British - Any ot...             Black
# 4   Asian/Asian British - Any other Asian background             Asian
# 5                    Other ethnic group - Not stated             White
# 8  Black/African/Caribbean/Black British - Caribbean             Asian
#
#                              legislation           purpose  \
# 0  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
# 1  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
# 4  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
# 5  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
# 8  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
#
#                         outcome                            coord  \
# 0  A no further action disposal            (51.460887, 0.005072)
# 1                        Arrest  (51.480146999999995, -0.507249)
# 4  A no further action disposal           (51.486675, -0.093976)
# 5          Community resolution           (51.509962, -0.131179)
# 8          Community resolution           (51.509962, -0.131179)
#
#   ethnicity_simple
# 0            White
# 1            Black
# 4            Asian
# 5       Not stated
# 8            Black

# %%
df_cleaned['ethnicity_simple'].value_counts()
# Out:
# White          74017
# Black          62333
# Not stated     34068
# Asian          32085
# Other           5797
# Mixed group     3865
# Name: ethnicity_simple, dtype: int64

# %% [markdown]
# ##1.5.2 Clean up officer ethnicity column

# %%
df_cleaned['officer_ethnicity'].value_counts()
# Out:
# White    83160
# Black    82994
# Asian    37488
# Other     8523
# Name: officer_ethnicity, dtype: int64

# %%
def func1(x):
    if 'White' in x:
        return 'White - officer'
    elif 'Black' in x:
        return 'Black - officer'
    elif 'Asian' in x:
        return 'Asian - officer'
    else:
        return 'Other - officer'

# %%
df_cleaned['ethnicity_officer'] = df_cleaned['officer_ethnicity'].apply(func1)
# Out:
# <ipython-input-85-2d4506b5d55c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['ethnicity_officer'] = df_cleaned['officer_ethnicity'].apply(func1)

# %%
df_cleaned.head()
# Out:
#    Unnamed: 0                       type                       date  \
# 0           0  Person and Vehicle search  2019-07-31T23:00:00+00:00
# 1           1  Person and Vehicle search  2019-07-31T23:02:00+00:00
# 4           4              Person search  2019-07-31T23:05:00+00:00
# 5           5              Person search  2019-07-31T23:05:00+00:00
# 8           8              Person search  2019-07-31T23:07:00+00:00
#
#    operation            latitude  longitude gender age_range  \
# 0        0.0           51.460887   0.005072   Male     25-34
# 1        0.0  51.480146999999995  -0.507249   Male     25-34
# 4        0.0           51.486675  -0.093976   Male     25-34
# 5        0.0           51.509962  -0.131179   Male     10-17
# 8        0.0           51.509962  -0.131179   Male     18-24
#
#                                            ethnicity officer_ethnicity  \
# 0  White - English/Welsh/Scottish/Northern Irish/...             White
# 1  Black/African/Caribbean/Black British - Any ot...             Black
# 4   Asian/Asian British - Any other Asian background             Asian
# 5                    Other ethnic group - Not stated             White
# 8  Black/African/Caribbean/Black British - Caribbean             Asian
#
#                              legislation           purpose  \
# 0  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
# 1  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
# 4  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
# 5  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
# 8  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
#
#                         outcome                            coord  \
# 0  A no further action disposal            (51.460887, 0.005072)
# 1                        Arrest  (51.480146999999995, -0.507249)
# 4  A no further action disposal           (51.486675, -0.093976)
# 5          Community resolution           (51.509962, -0.131179)
# 8          Community resolution           (51.509962, -0.131179)
#
#   ethnicity_simple ethnicity_officer
# 0            White   White - officer
# 1            Black   Black - officer
# 4            Asian   Asian - officer
# 5       Not stated   White - officer
# 8            Black   Asian - officer

# %% [markdown]
# ##1.5.3 Clean up gender column

# %%
df_cleaned['gender'].value_counts()
# Out:
# Male      197801
# Female     14303
# Other         61
# Name: gender, dtype: int64

# %%
def func2(x):
    if 'Other' in x:
        return 'Other gender'
    elif 'Male' in x:
        return 'Male'
    else:
        return 'Female'

# %%
df_cleaned['gender_clean'] = df_cleaned['gender'].apply(func2)
# Out:
# <ipython-input-89-c90c2028b422>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['gender_clean'] = df_cleaned['gender'].apply(func2)

# %%
df_cleaned['gender_clean'].value_counts()
# Out:
# Male            197801
# Female           14303
# Other gender        61
# Name: gender_clean, dtype: int64

# %%
df_cleaned.to_csv('cleaned_stop_data.csv')

# %% [markdown]
# ##1.6 Convert stop and search data GeoJSON

# %%
file = 'cleaned_stop_data.csv'
points = pd.read_csv(file)
points = pd.DataFrame(points)
points.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212165 entries, 0 to 212164
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         212165 non-null  int64
#  1   Unnamed: 0.1       212165 non-null  int64
#  2   type               212165 non-null  object
#  3   date               212165 non-null  object
#  4   operation          212165 non-null  float64
#  5   latitude           212165 non-null  float64
#  6   longitude          212165 non-null  float64
#  7   gender             212165 non-null  object
#  8   age_range          212165 non-null  object
#  9   ethnicity          212165 non-null  object
#  10  officer_ethnicity  212165 non-null  object
#  11  legislation        212165 non-null  object
#  12  purpose            212165 non-null  object
#  13  outcome            212165 non-null  object
#  14  coord              212165 non-null  object
#  15  ethnicity_simple   212165 non-null  object
#  16  ethnicity_officer  212165 non-null  object
#  17  gender_clean       212165 non-null  object
# dtypes: float64(3), int64(2), object(13)
# memory usage: 29.1+ MB

# %%
points_df = gdf(points, geometry=gpd.points_from_xy(points.longitude, points.latitude))
points_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                       type  \
# 0           0             0  Person and Vehicle search
# 1           1             1  Person and Vehicle search
# 2           4             4              Person search
# 3           5             5              Person search
# 4           8             8              Person search
#
#                         date  operation   latitude  longitude gender  \
# 0  2019-07-31T23:00:00+00:00        0.0  51.460887   0.005072   Male
# 1  2019-07-31T23:02:00+00:00        0.0  51.480147  -0.507249   Male
# 2  2019-07-31T23:05:00+00:00        0.0  51.486675  -0.093976   Male
# 3  2019-07-31T23:05:00+00:00        0.0  51.509962  -0.131179   Male
# 4  2019-07-31T23:07:00+00:00        0.0  51.509962  -0.131179   Male
#
#   age_range                                          ethnicity  \
# 0     25-34  White - English/Welsh/Scottish/Northern Irish/...
# 1     25-34  Black/African/Caribbean/Black British - Any ot...
# 2     25-34   Asian/Asian British - Any other Asian background
# 3     10-17                    Other ethnic group - Not stated
# 4     18-24  Black/African/Caribbean/Black British - Caribbean
#
#   officer_ethnicity                            legislation           purpose  \
# 0             White  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
# 1             Black  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
# 2             Asian  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
# 3             White  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
# 4             Asian  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
#
#                         outcome                            coord  \
# 0  A no further action disposal            (51.460887, 0.005072)
# 1                        Arrest  (51.480146999999995, -0.507249)
# 2  A no further action disposal           (51.486675, -0.093976)
# 3          Community resolution           (51.509962, -0.131179)
# 4          Community resolution           (51.509962, -0.131179)
#
#   ethnicity_simple ethnicity_officer gender_clean                   geometry
# 0            White   White - officer         Male   POINT (0.00507 51.46089)
# 1            Black   Black - officer         Male  POINT (-0.50725 51.48015)
# 2            Asian   Asian - officer         Male  POINT (-0.09398 51.48667)
# 3       Not stated   White - officer         Male  POINT (-0.13118 51.50996)
# 4            Black   Asian - officer         Male  POINT (-0.13118 51.50996)

# %%
print(points_df.crs)
# Out:
# None

# %%
points_df.crs = {"init":"epsg:4326"}
print(points_df.crs)
# Out:
# {'init': 'epsg:4326'}

# %% [markdown]
# ##1.6.1 Add borough data for each stop and search
# Add London borough data and determine where each stop and seach occured, and add that information to stop and search dataframe.

# %%
borough_file = 'id_london.json'
boro_df = gpd.read_file(borough_file)

# %%
boro_df.head()
# Out:
#    id                  name       code  area_hectares  inner_statistical  \
# 0   1  Kingston upon Thames  E09000021       3726.117              False
# 1   2               Croydon  E09000008       8649.441              False
# 2   3               Bromley  E09000006      15013.487              False
# 3   4              Hounslow  E09000018       5658.541              False
# 4   5                Ealing  E09000009       5554.428              False
#
#                                             geometry
# 0  MULTIPOLYGON (((-0.33068 51.32901, -0.33059 51...
# 1  MULTIPOLYGON (((-0.06402 51.31864, -0.06408 51...
# 2  MULTIPOLYGON (((0.01213 51.29960, 0.01196 51.2...
# 3  MULTIPOLYGON (((-0.24456 51.48870, -0.24468 51...
# 4  MULTIPOLYGON (((-0.41183 51.53408, -0.41188 51...

# %%
boro_df = boro_df.sort_values('name')
boro_df
# Out:
#     id                    name       code  area_hectares  inner_statistical  \
# 31  32    Barking and Dagenham  E09000002       3779.934              False
# 9   10                  Barnet  E09000003       8674.837              False
# 14  15                  Bexley  E09000004       6428.649              False
# 8    9                   Brent  E09000005       4323.270              False
# 2    3                 Bromley  E09000006      15013.487              False
# 25  26                  Camden  E09000007       2178.932               True
# 32  33          City of London  E09000001        314.942               True
# 1    2                 Croydon  E09000008       8649.441              False
# 4    5                  Ealing  E09000009       5554.428              False
# 15  16                 Enfield  E09000010       8220.025              False
# 13  14               Greenwich  E09000011       5044.190              False
# 28  29                 Hackney  E09000012       1904.902               True
# 22  23  Hammersmith and Fulham  E09000013       1715.409               True
# 29  30                Haringey  E09000014       2959.837               True
# 7    8                  Harrow  E09000015       5046.330              False
# 5    6                Havering  E09000016      11445.735              False
# 6    7              Hillingdon  E09000017      11570.063              False
# 3    4                Hounslow  E09000018       5658.541              False
# 27  28               Islington  E09000019       1485.664               True
# 23  24  Kensington and Chelsea  E09000020       1238.379               True
# 0    1    Kingston upon Thames  E09000021       3726.117              False
# 10  11                 Lambeth  E09000022       2724.940               True
# 12  13                Lewisham  E09000023       3531.706               True
# 20  21                  Merton  E09000024       3762.466              False
# 30  31                  Newham  E09000025       3857.806               True
# 17  18               Redbridge  E09000026       5644.225              False
# 19  20    Richmond upon Thames  E09000027       5876.111              False
# 11  12               Southwark  E09000028       2991.340               True
# 18  19                  Sutton  E09000029       4384.698              False
# 26  27           Tower Hamlets  E09000030       2157.501               True
# 16  17          Waltham Forest  E09000031       3880.793              False
# 21  22              Wandsworth  E09000032       3522.022               True
# 24  25             Westminster  E09000033       2203.005               True
#
#                                              geometry
# 31  MULTIPOLYGON (((0.06971 51.54406, 0.07035 51.5...
# 9   MULTIPOLYGON (((-0.19990 51.67017, -0.19970 51...
# 14  MULTIPOLYGON (((0.12021 51.51144, 0.12159 51.5...
# 8   MULTIPOLYGON (((-0.19657 51.52765, -0.19685 51...
# 2   MULTIPOLYGON (((0.01213 51.29960, 0.01196 51.2...
# 25  MULTIPOLYGON (((-0.14242 51.56912, -0.14250 51...
# 32  MULTIPOLYGON (((-0.11157 51.51075, -0.11159 51...
# 1   MULTIPOLYGON (((-0.06402 51.31864, -0.06408 51...
# 4   MULTIPOLYGON (((-0.41183 51.53408, -0.41188 51...
# 15  MULTIPOLYGON (((-0.10580 51.69187, -0.10557 51...
# 13  MULTIPOLYGON (((0.12021 51.51144, 0.12054 51.5...
# 28  MULTIPOLYGON (((-0.09766 51.57365, -0.09756 51...
# 22  MULTIPOLYGON (((-0.24456 51.48870, -0.24460 51...
# 29  MULTIPOLYGON (((-0.09766 51.57365, -0.09780 51...
# 7   MULTIPOLYGON (((-0.40407 51.61318, -0.40320 51...
# 5   MULTIPOLYGON (((0.15869 51.51219, 0.15871 51.5...
# 6   MULTIPOLYGON (((-0.40407 51.61318, -0.40388 51...
# 3   MULTIPOLYGON (((-0.24456 51.48870, -0.24468 51...
# 27  MULTIPOLYGON (((-0.13839 51.55686, -0.13852 51...
# 23  MULTIPOLYGON (((-0.18388 51.47742, -0.18403 51...
# 0   MULTIPOLYGON (((-0.33068 51.32901, -0.33059 51...
# 10  MULTIPOLYGON (((-0.12846 51.48505, -0.12843 51...
# 12  MULTIPOLYGON (((-0.03241 51.49306, -0.03240 51...
# 20  MULTIPOLYGON (((-0.13432 51.39093, -0.13438 51...
# 30  MULTIPOLYGON (((-0.00786 51.52301, -0.00811 51...
# 17  MULTIPOLYGON (((0.06937 51.54413, 0.06910 51.5...
# 19  MULTIPOLYGON (((-0.32173 51.46541, -0.32172 51...
# 11  MULTIPOLYGON (((-0.10892 51.50844, -0.10889 51...
# 18  MULTIPOLYGON (((-0.15657 51.32151, -0.15866 51...
# 26  MULTIPOLYGON (((-0.07938 51.50784, -0.07935 51...
# 16  MULTIPOLYGON (((0.01924 51.60822, 0.01931 51.6...
# 21  MULTIPOLYGON (((-0.22343 51.47152, -0.22327 51...
# 24  MULTIPOLYGON (((-0.15000 51.48548, -0.15009 51...

# %%
df = gpd.sjoin(points_df, boro_df, how='left', op='within')

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                       type  \
# 0           0             0  Person and Vehicle search
# 1           1             1  Person and Vehicle search
# 2           4             4              Person search
# 3           5             5              Person search
# 4           8             8              Person search
#
#                         date  operation   latitude  longitude gender  \
# 0  2019-07-31T23:00:00+00:00        0.0  51.460887   0.005072   Male
# 1  2019-07-31T23:02:00+00:00        0.0  51.480147  -0.507249   Male
# 2  2019-07-31T23:05:00+00:00        0.0  51.486675  -0.093976   Male
# 3  2019-07-31T23:05:00+00:00        0.0  51.509962  -0.131179   Male
# 4  2019-07-31T23:07:00+00:00        0.0  51.509962  -0.131179   Male
#
#   age_range                                          ethnicity  \
# 0     25-34  White - English/Welsh/Scottish/Northern Irish/...
# 1     25-34  Black/African/Caribbean/Black British - Any ot...
# 2     25-34   Asian/Asian British - Any other Asian background
# 3     10-17                    Other ethnic group - Not stated
# 4     18-24  Black/African/Caribbean/Black British - Caribbean
#
#   officer_ethnicity                            legislation           purpose  \
# 0             White  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
# 1             Black  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
# 2             Asian  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
# 3             White  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
# 4             Asian  Misuse of Drugs Act 1971 (section 23)  Controlled drugs
#
#                         outcome                            coord  \
# 0  A no further action disposal            (51.460887, 0.005072)
# 1                        Arrest  (51.480146999999995, -0.507249)
# 2  A no further action disposal           (51.486675, -0.093976)
# 3          Community resolution           (51.509962, -0.131179)
# 4          Community resolution           (51.509962, -0.131179)
#
#   ethnicity_simple ethnicity_officer gender_clean                   geometry  \
# 0            White   White - officer         Male   POINT (0.00507 51.46089)
# 1            Black   Black - officer         Male  POINT (-0.50725 51.48015)
# 2            Asian   Asian - officer         Male  POINT (-0.09398 51.48667)
# 3       Not stated   White - officer         Male  POINT (-0.13118 51.50996)
# 4            Black   Asian - officer         Male  POINT (-0.13118 51.50996)
#
#    index_right    id         name       code  area_hectares inner_statistical
# 0         12.0  13.0     Lewisham  E09000023       3531.706              True
# 1          NaN   NaN          NaN        NaN            NaN               NaN
# 2         11.0  12.0    Southwark  E09000028       2991.340              True
# 3         24.0  25.0  Westminster  E09000033       2203.005              True
# 4         24.0  25.0  Westminster  E09000033       2203.005              True

# %%
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 212165 entries, 0 to 212164
# Data columns (total 25 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         212165 non-null  int64
#  1   Unnamed: 0.1       212165 non-null  int64
#  2   type               212165 non-null  object
#  3   date               212165 non-null  object
#  4   operation          212165 non-null  float64
#  5   latitude           212165 non-null  float64
#  6   longitude          212165 non-null  float64
#  7   gender             212165 non-null  object
#  8   age_range          212165 non-null  object
#  9   ethnicity          212165 non-null  object
#  10  officer_ethnicity  212165 non-null  object
#  11  legislation        212165 non-null  object
#  12  purpose            212165 non-null  object
#  13  outcome            212165 non-null  object
#  14  coord              212165 non-null  object
#  15  ethnicity_simple   212165 non-null  object
#  16  ethnicity_officer  212165 non-null  object
#  17  gender_clean       212165 non-null  object
#  18  geometry           212165 non-null  geometry
#  19  index_right        211546 non-null  float64
#  20  id                 211546 non-null  float64
#  21  name               211546 non-null  object
#  22  code               211546 non-null  object
#  23  area_hectares      211546 non-null  float64
#  24  inner_statistical  211546 non-null  object
# dtypes: float64(6), geometry(1), int64(2), object(16)
# memory usage: 42.1+ MB

# %% [markdown]
# ##1.6.2 Trim dataframe to only columns to export to JSON
# Also change column names to appropriately

# %%
use = ['type', 'date', 'gender_clean', 'age_range', 'ethnicity', 'ethnicity_simple', 'purpose', 'legislation', 'outcome', 'name','ethnicity_officer', 'geometry']
df_toJson = df[use]
df_toJson.head()
# Out:
#                         type                       date gender_clean  \
# 0  Person and Vehicle search  2019-07-31T23:00:00+00:00         Male
# 1  Person and Vehicle search  2019-07-31T23:02:00+00:00         Male
# 2              Person search  2019-07-31T23:05:00+00:00         Male
# 3              Person search  2019-07-31T23:05:00+00:00         Male
# 4              Person search  2019-07-31T23:07:00+00:00         Male
#
#   age_range                                          ethnicity  \
# 0     25-34  White - English/Welsh/Scottish/Northern Irish/...
# 1     25-34  Black/African/Caribbean/Black British - Any ot...
# 2     25-34   Asian/Asian British - Any other Asian background
# 3     10-17                    Other ethnic group - Not stated
# 4     18-24  Black/African/Caribbean/Black British - Caribbean
#
#   ethnicity_simple           purpose                            legislation  \
# 0            White  Controlled drugs  Misuse of Drugs Act 1971 (section 23)
# 1            Black  Controlled drugs  Misuse of Drugs Act 1971 (section 23)
# 2            Asian  Controlled drugs  Misuse of Drugs Act 1971 (section 23)
# 3       Not stated  Controlled drugs  Misuse of Drugs Act 1971 (section 23)
# 4            Black  Controlled drugs  Misuse of Drugs Act 1971 (section 23)
#
#                         outcome         name ethnicity_officer  \
# 0  A no further action disposal     Lewisham   White - officer
# 1                        Arrest          NaN   Black - officer
# 2  A no further action disposal    Southwark   Asian - officer
# 3          Community resolution  Westminster   White - officer
# 4          Community resolution  Westminster   Asian - officer
#
#                     geometry
# 0   POINT (0.00507 51.46089)
# 1  POINT (-0.50725 51.48015)
# 2  POINT (-0.09398 51.48667)
# 3  POINT (-0.13118 51.50996)
# 4  POINT (-0.13118 51.50996)

# %%
df_toJson.rename({'gender_clean': 'gender'}, axis=1, inplace=True)
df_toJson.rename({'ethnicity': 'old_ethnicity'}, axis=1, inplace=True)
# Out:
# /opt/anaconda3/envs/london-data/lib/python3.8/site-packages/pandas/core/frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_toJson.rename({'ethnicity_simple': 'ethnicity'}, axis=1, inplace=True)
df_toJson.rename({'ethnicity_officer': 'officer_ethnicity'}, axis=1, inplace=True)
df_toJson.head()
# Out:
#                         type                       date gender age_range  \
# 0  Person and Vehicle search  2019-07-31T23:00:00+00:00   Male     25-34
# 1  Person and Vehicle search  2019-07-31T23:02:00+00:00   Male     25-34
# 2              Person search  2019-07-31T23:05:00+00:00   Male     25-34
# 3              Person search  2019-07-31T23:05:00+00:00   Male     10-17
# 4              Person search  2019-07-31T23:07:00+00:00   Male     18-24
#
#                                        old_ethnicity   ethnicity  \
# 0  White - English/Welsh/Scottish/Northern Irish/...       White
# 1  Black/African/Caribbean/Black British - Any ot...       Black
# 2   Asian/Asian British - Any other Asian background       Asian
# 3                    Other ethnic group - Not stated  Not stated
# 4  Black/African/Caribbean/Black British - Caribbean       Black
#
#             purpose                            legislation  \
# 0  Controlled drugs  Misuse of Drugs Act 1971 (section 23)
# 1  Controlled drugs  Misuse of Drugs Act 1971 (section 23)
# 2  Controlled drugs  Misuse of Drugs Act 1971 (section 23)
# 3  Controlled drugs  Misuse of Drugs Act 1971 (section 23)
# 4  Controlled drugs  Misuse of Drugs Act 1971 (section 23)
#
#                         outcome         name officer_ethnicity  \
# 0  A no further action disposal     Lewisham   White - officer
# 1                        Arrest          NaN   Black - officer
# 2  A no further action disposal    Southwark   Asian - officer
# 3          Community resolution  Westminster   White - officer
# 4          Community resolution  Westminster   Asian - officer
#
#                     geometry
# 0   POINT (0.00507 51.46089)
# 1  POINT (-0.50725 51.48015)
# 2  POINT (-0.09398 51.48667)
# 3  POINT (-0.13118 51.50996)
# 4  POINT (-0.13118 51.50996)

# %%
df_toJson.to_file("points.geojson", driver='GeoJSON')

# %% [markdown]
# #2 Reshape London GeoJSON
# ##2.1 Add total stop and searches per borough
# Download London borough GeoJSON and for each borough add property "total" that tallies the total number of stops per borough.

# %%
boroughs = pd.DataFrame(df_toJson.name.value_counts().reset_index().values, columns=["name", "total"])
borough_total = boroughs.sort_index(axis = 0, ascending=True)

# %%
borough_total.head()
# Out:
#             name  total
# 0    Westminster  15165
# 1         Newham  14008
# 2      Southwark  13088
# 3  Tower Hamlets  12891
# 4        Lambeth  11973

# %%
merged = pd.merge(boro_df, borough_total, left_on='name', right_on='name', how='left')
merged_df = pd.DataFrame(data=merged)

# %%
merged_df.head()
# Out:
#    id                  name       code  area_hectares  inner_statistical  \
# 0  32  Barking and Dagenham  E09000002       3779.934              False
# 1  10                Barnet  E09000003       8674.837              False
# 2  15                Bexley  E09000004       6428.649              False
# 3   9                 Brent  E09000005       4323.270              False
# 4   3               Bromley  E09000006      15013.487              False
#
#                                             geometry total
# 0  MULTIPOLYGON (((0.06971 51.54406, 0.07035 51.5...  4225
# 1  MULTIPOLYGON (((-0.19990 51.67017, -0.19970 51...  2661
# 2  MULTIPOLYGON (((0.12021 51.51144, 0.12159 51.5...  2903
# 3  MULTIPOLYGON (((-0.19657 51.52765, -0.19685 51...  7235
# 4  MULTIPOLYGON (((0.01213 51.29960, 0.01196 51.2...  5795

# %%
merged_df['total'] = pd.to_numeric(merged_df['total'])
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 0 to 32
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 33 non-null     int64
#  1   name               33 non-null     object
#  2   code               33 non-null     object
#  3   area_hectares      33 non-null     float64
#  4   inner_statistical  33 non-null     bool
#  5   geometry           33 non-null     geometry
#  6   total              33 non-null     int64
# dtypes: bool(1), float64(1), geometry(1), int64(2), object(2)
# memory usage: 1.8+ KB

# %%
geo_frame = gdf(merged_df, crs="EPSG:4326", geometry=merged_df['geometry'])
geo_frame.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 33 entries, 0 to 32
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 33 non-null     int64
#  1   name               33 non-null     object
#  2   code               33 non-null     object
#  3   area_hectares      33 non-null     float64
#  4   inner_statistical  33 non-null     bool
#  5   geometry           33 non-null     geometry
#  6   total              33 non-null     int64
# dtypes: bool(1), float64(1), geometry(1), int64(2), object(2)
# memory usage: 1.8+ KB

# %%
df_toJson.head()
# Out:
#                         type                       date gender age_range  \
# 0  Person and Vehicle search  2019-07-31T23:00:00+00:00   Male     25-34
# 1  Person and Vehicle search  2019-07-31T23:02:00+00:00   Male     25-34
# 2              Person search  2019-07-31T23:05:00+00:00   Male     25-34
# 3              Person search  2019-07-31T23:05:00+00:00   Male     10-17
# 4              Person search  2019-07-31T23:07:00+00:00   Male     18-24
#
#                                        old_ethnicity   ethnicity  \
# 0  White - English/Welsh/Scottish/Northern Irish/...       White
# 1  Black/African/Caribbean/Black British - Any ot...       Black
# 2   Asian/Asian British - Any other Asian background       Asian
# 3                    Other ethnic group - Not stated  Not stated
# 4  Black/African/Caribbean/Black British - Caribbean       Black
#
#             purpose                            legislation  \
# 0  Controlled drugs  Misuse of Drugs Act 1971 (section 23)
# 1  Controlled drugs  Misuse of Drugs Act 1971 (section 23)
# 2  Controlled drugs  Misuse of Drugs Act 1971 (section 23)
# 3  Controlled drugs  Misuse of Drugs Act 1971 (section 23)
# 4  Controlled drugs  Misuse of Drugs Act 1971 (section 23)
#
#                         outcome         name officer_ethnicity  \
# 0  A no further action disposal     Lewisham   White - officer
# 1                        Arrest          NaN   Black - officer
# 2  A no further action disposal    Southwark   Asian - officer
# 3          Community resolution  Westminster   White - officer
# 4          Community resolution  Westminster   Asian - officer
#
#                     geometry
# 0   POINT (0.00507 51.46089)
# 1  POINT (-0.50725 51.48015)
# 2  POINT (-0.09398 51.48667)
# 3  POINT (-0.13118 51.50996)
# 4  POINT (-0.13118 51.50996)

# %% [markdown]
# ##2.2 Get age range totals
# Get total of age range per borough

# %%
age_totals = pd.DataFrame(df_toJson.pivot_table(index=['name'], columns=['age_range'], aggfunc='size', fill_value=0)).reset_index().rename_axis(None,axis=1)
age_totals.head()
# Out:
#                    name  10-17  18-24  25-34  over 34  under 10
# 0  Barking and Dagenham    969   1558   1090      606         2
# 1                Barnet    645   1026    572      417         1
# 2                Bexley    842   1071    601      388         1
# 3                 Brent   1369   3148   1680     1038         0
# 4               Bromley   1686   1981   1078     1048         2

# %% [markdown]
# ##2.3 Get gender totals
# Get total number of stop and searches per gender per borough

# %%
gender_totals = pd.DataFrame(df_toJson.pivot_table(index=['name'], columns=['gender'], aggfunc='size', fill_value=0)).reset_index().rename_axis(None,axis=1)
gender_totals.head()
# Out:
#                    name  Female  Male  Other gender
# 0  Barking and Dagenham     277  3947             1
# 1                Barnet     178  2481             2
# 2                Bexley     227  2675             1
# 3                 Brent     375  6859             1
# 4               Bromley     708  5085             2

# %% [markdown]
# ##2.4 Get ethnicity totals
# Get total number of stop and searches per ethnicity per borough

# %%
ethnicity_totals = pd.DataFrame(df_toJson.pivot_table(index=['name'], columns=['ethnicity'], aggfunc='size', fill_value=0)).reset_index().rename_axis(None,axis=1)
ethnicity_totals.head()
# Out:
#                    name  Asian  Black  Mixed group  Not stated  Other  White
# 0  Barking and Dagenham    755   1072           69         272    101   1956
# 1                Barnet    304    630           85         438    132   1072
# 2                Bexley     95    432           38         210     30   2098
# 3                 Brent   1023   2872          151        1283    254   1652
# 4               Bromley    166   1201           98         551     82   3697

# %% [markdown]
# ##2.5 Get officer ethnicity totals
# Get total number of stop and searches per officer ethnicity per borough

# %%
officer_totals = pd.DataFrame(df_toJson.pivot_table(index=['name'], columns=['officer_ethnicity'], aggfunc='size', fill_value=0)).reset_index().rename_axis(None,axis=1)
officer_totals.head()
# Out:
#                    name  Asian - officer  Black - officer  Other - officer  \
# 0  Barking and Dagenham              845             1244               38
# 1                Barnet              337              832              286
# 2                Bexley              132              542               35
# 3                 Brent             1190             3692              494
# 4               Bromley              235             1580               59
#
#    White - officer
# 0             2098
# 1             1206
# 2             2194
# 3             1859
# 4             3921

# %% [markdown]
# ##2.6 Get purpose totals
# Get total number of stop and searches per purpose of stops per borough

# %%
purpose_totals = pd.DataFrame(df_toJson.pivot_table(index=['name'], columns=['purpose'], aggfunc='size', fill_value=0)).reset_index().rename_axis(None,axis=1)
purpose_totals.head()
# Out:
#                    name  Anything to threaten or harm anyone  \
# 0  Barking and Dagenham                                  106
# 1                Barnet                                   32
# 2                Bexley                                   71
# 3                 Brent                                  264
# 4               Bromley                                   91
#
#    Articles for use in criminal damage  Controlled drugs  \
# 0                                   11              2664
# 1                                    4              1461
# 2                                   26              1724
# 3                                   19              4529
# 4                                   97              2808
#
#    Evidence of offences under the Act  Firearms  Fireworks  Offensive weapons  \
# 0                                 200        26         20                664
# 1                                 273        24         16                437
# 2                                 289         9         34                356
# 3                                 324        51         18               1348
# 4                                 654        22         16               1014
#
#    Stolen goods
# 0           534
# 1           414
# 2           394
# 3           682
# 4          1093

# %% [markdown]
# ##2.7 Get type totals
# Get total number of stop and searches per type of stops per borough

# %%
type_totals = pd.DataFrame(df_toJson.pivot_table(index=['name'], columns=['type'], aggfunc='size', fill_value=0)).reset_index().rename_axis(None,axis=1)
type_totals.head()
# Out:
#                    name  Person and Vehicle search  Person search  \
# 0  Barking and Dagenham                       1076           3134
# 1                Barnet                        740           1917
# 2                Bexley                        712           2185
# 3                 Brent                       1931           5283
# 4               Bromley                       1120           4665
#
#    Vehicle search
# 0              15
# 1               4
# 2               6
# 3              21
# 4              10

# %% [markdown]
# ##2.8 Add all totals to London GeoJSON

# %%
two = type_totals.merge(purpose_totals, on='name')
three = two.merge(officer_totals, on='name')
four = three.merge(ethnicity_totals, on='name')
five = four.merge(gender_totals, on='name')
six = five.merge(age_totals, on='name')
totals_df = six.merge(merged_df, on='name')
totals_df.head()
# Out:
#                    name  Person and Vehicle search  Person search  \
# 0  Barking and Dagenham                       1076           3134
# 1                Barnet                        740           1917
# 2                Bexley                        712           2185
# 3                 Brent                       1931           5283
# 4               Bromley                       1120           4665
#
#    Vehicle search  Anything to threaten or harm anyone  \
# 0              15                                  106
# 1               4                                   32
# 2               6                                   71
# 3              21                                  264
# 4              10                                   91
#
#    Articles for use in criminal damage  Controlled drugs  \
# 0                                   11              2664
# 1                                    4              1461
# 2                                   26              1724
# 3                                   19              4529
# 4                                   97              2808
#
#    Evidence of offences under the Act  Firearms  Fireworks  Offensive weapons  \
# 0                                 200        26         20                664
# 1                                 273        24         16                437
# 2                                 289         9         34                356
# 3                                 324        51         18               1348
# 4                                 654        22         16               1014
#
#    Stolen goods  Asian - officer  Black - officer  Other - officer  \
# 0           534              845             1244               38
# 1           414              337              832              286
# 2           394              132              542               35
# 3           682             1190             3692              494
# 4          1093              235             1580               59
#
#    White - officer  Asian  Black  Mixed group  Not stated  Other  White  \
# 0             2098    755   1072           69         272    101   1956
# 1             1206    304    630           85         438    132   1072
# 2             2194     95    432           38         210     30   2098
# 3             1859   1023   2872          151        1283    254   1652
# 4             3921    166   1201           98         551     82   3697
#
#    Female  Male  Other gender  10-17  18-24  25-34  over 34  under 10  id  \
# 0     277  3947             1    969   1558   1090      606         2  32
# 1     178  2481             2    645   1026    572      417         1  10
# 2     227  2675             1    842   1071    601      388         1  15
# 3     375  6859             1   1369   3148   1680     1038         0   9
# 4     708  5085             2   1686   1981   1078     1048         2   3
#
#         code  area_hectares  inner_statistical  \
# 0  E09000002       3779.934              False
# 1  E09000003       8674.837              False
# 2  E09000004       6428.649              False
# 3  E09000005       4323.270              False
# 4  E09000006      15013.487              False
#
#                                             geometry  total
# 0  MULTIPOLYGON (((0.06971 51.54406, 0.07035 51.5...   4225
# 1  MULTIPOLYGON (((-0.19990 51.67017, -0.19970 51...   2661
# 2  MULTIPOLYGON (((0.12021 51.51144, 0.12159 51.5...   2903
# 3  MULTIPOLYGON (((-0.19657 51.52765, -0.19685 51...   7235
# 4  MULTIPOLYGON (((0.01213 51.29960, 0.01196 51.2...   5795

# %%
totals_geo = gdf(totals_df, crs="EPSG:4326")
totals_geo.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 33 entries, 0 to 32
# Data columns (total 36 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   name                                 33 non-null     object
#  1   Person and Vehicle search            33 non-null     int64
#  2   Person search                        33 non-null     int64
#  3   Vehicle search                       33 non-null     int64
#  4   Anything to threaten or harm anyone  33 non-null     int64
#  5   Articles for use in criminal damage  33 non-null     int64
#  6   Controlled drugs                     33 non-null     int64
#  7   Evidence of offences under the Act   33 non-null     int64
#  8   Firearms                             33 non-null     int64
#  9   Fireworks                            33 non-null     int64
#  10  Offensive weapons                    33 non-null     int64
#  11  Stolen goods                         33 non-null     int64
#  12  Asian - officer                      33 non-null     int64
#  13  Black - officer                      33 non-null     int64
#  14  Other - officer                      33 non-null     int64
#  15  White - officer                      33 non-null     int64
#  16  Asian                                33 non-null     int64
#  17  Black                                33 non-null     int64
#  18  Mixed group                          33 non-null     int64
#  19  Not stated                           33 non-null     int64
#  20  Other                                33 non-null     int64
#  21  White                                33 non-null     int64
#  22  Female                               33 non-null     int64
#  23  Male                                 33 non-null     int64
#  24  Other gender                         33 non-null     int64
#  25  10-17                                33 non-null     int64
#  26  18-24                                33 non-null     int64
#  27  25-34                                33 non-null     int64
#  28  over 34                              33 non-null     int64
#  29  under 10                             33 non-null     int64
#  30  id                                   33 non-null     int64
#  31  code                                 33 non-null     object
#  32  area_hectares                        33 non-null     float64
#  33  inner_statistical                    33 non-null     bool
#  34  geometry                             33 non-null     geometry
#  35  total                                33 non-null     int64
# dtypes: bool(1), float64(1), geometry(1), int64(31), object(2)
# memory usage: 9.3+ KB

# %%
totals_geo.head()
# Out:
#                    name  Person and Vehicle search  Person search  \
# 0  Barking and Dagenham                       1076           3134
# 1                Barnet                        740           1917
# 2                Bexley                        712           2185
# 3                 Brent                       1931           5283
# 4               Bromley                       1120           4665
#
#    Vehicle search  Anything to threaten or harm anyone  \
# 0              15                                  106
# 1               4                                   32
# 2               6                                   71
# 3              21                                  264
# 4              10                                   91
#
#    Articles for use in criminal damage  Controlled drugs  \
# 0                                   11              2664
# 1                                    4              1461
# 2                                   26              1724
# 3                                   19              4529
# 4                                   97              2808
#
#    Evidence of offences under the Act  Firearms  Fireworks  Offensive weapons  \
# 0                                 200        26         20                664
# 1                                 273        24         16                437
# 2                                 289         9         34                356
# 3                                 324        51         18               1348
# 4                                 654        22         16               1014
#
#    Stolen goods  Asian - officer  Black - officer  Other - officer  \
# 0           534              845             1244               38
# 1           414              337              832              286
# 2           394              132              542               35
# 3           682             1190             3692              494
# 4          1093              235             1580               59
#
#    White - officer  Asian  Black  Mixed group  Not stated  Other  White  \
# 0             2098    755   1072           69         272    101   1956
# 1             1206    304    630           85         438    132   1072
# 2             2194     95    432           38         210     30   2098
# 3             1859   1023   2872          151        1283    254   1652
# 4             3921    166   1201           98         551     82   3697
#
#    Female  Male  Other gender  10-17  18-24  25-34  over 34  under 10  id  \
# 0     277  3947             1    969   1558   1090      606         2  32
# 1     178  2481             2    645   1026    572      417         1  10
# 2     227  2675             1    842   1071    601      388         1  15
# 3     375  6859             1   1369   3148   1680     1038         0   9
# 4     708  5085             2   1686   1981   1078     1048         2   3
#
#         code  area_hectares  inner_statistical  \
# 0  E09000002       3779.934              False
# 1  E09000003       8674.837              False
# 2  E09000004       6428.649              False
# 3  E09000005       4323.270              False
# 4  E09000006      15013.487              False
#
#                                             geometry  total
# 0  MULTIPOLYGON (((0.06971 51.54406, 0.07035 51.5...   4225
# 1  MULTIPOLYGON (((-0.19990 51.67017, -0.19970 51...   2661
# 2  MULTIPOLYGON (((0.12021 51.51144, 0.12159 51.5...   2903
# 3  MULTIPOLYGON (((-0.19657 51.52765, -0.19685 51...   7235
# 4  MULTIPOLYGON (((0.01213 51.29960, 0.01196 51.2...   5795

# %%
boro_df
# Out:
#     id                    name       code  area_hectares  inner_statistical  \
# 31  32    Barking and Dagenham  E09000002       3779.934              False
# 9   10                  Barnet  E09000003       8674.837              False
# 14  15                  Bexley  E09000004       6428.649              False
# 8    9                   Brent  E09000005       4323.270              False
# 2    3                 Bromley  E09000006      15013.487              False
# 25  26                  Camden  E09000007       2178.932               True
# 32  33          City of London  E09000001        314.942               True
# 1    2                 Croydon  E09000008       8649.441              False
# 4    5                  Ealing  E09000009       5554.428              False
# 15  16                 Enfield  E09000010       8220.025              False
# 13  14               Greenwich  E09000011       5044.190              False
# 28  29                 Hackney  E09000012       1904.902               True
# 22  23  Hammersmith and Fulham  E09000013       1715.409               True
# 29  30                Haringey  E09000014       2959.837               True
# 7    8                  Harrow  E09000015       5046.330              False
# 5    6                Havering  E09000016      11445.735              False
# 6    7              Hillingdon  E09000017      11570.063              False
# 3    4                Hounslow  E09000018       5658.541              False
# 27  28               Islington  E09000019       1485.664               True
# 23  24  Kensington and Chelsea  E09000020       1238.379               True
# 0    1    Kingston upon Thames  E09000021       3726.117              False
# 10  11                 Lambeth  E09000022       2724.940               True
# 12  13                Lewisham  E09000023       3531.706               True
# 20  21                  Merton  E09000024       3762.466              False
# 30  31                  Newham  E09000025       3857.806               True
# 17  18               Redbridge  E09000026       5644.225              False
# 19  20    Richmond upon Thames  E09000027       5876.111              False
# 11  12               Southwark  E09000028       2991.340               True
# 18  19                  Sutton  E09000029       4384.698              False
# 26  27           Tower Hamlets  E09000030       2157.501               True
# 16  17          Waltham Forest  E09000031       3880.793              False
# 21  22              Wandsworth  E09000032       3522.022               True
# 24  25             Westminster  E09000033       2203.005               True
#
#                                              geometry
# 31  MULTIPOLYGON (((0.06971 51.54406, 0.07035 51.5...
# 9   MULTIPOLYGON (((-0.19990 51.67017, -0.19970 51...
# 14  MULTIPOLYGON (((0.12021 51.51144, 0.12159 51.5...
# 8   MULTIPOLYGON (((-0.19657 51.52765, -0.19685 51...
# 2   MULTIPOLYGON (((0.01213 51.29960, 0.01196 51.2...
# 25  MULTIPOLYGON (((-0.14242 51.56912, -0.14250 51...
# 32  MULTIPOLYGON (((-0.11157 51.51075, -0.11159 51...
# 1   MULTIPOLYGON (((-0.06402 51.31864, -0.06408 51...
# 4   MULTIPOLYGON (((-0.41183 51.53408, -0.41188 51...
# 15  MULTIPOLYGON (((-0.10580 51.69187, -0.10557 51...
# 13  MULTIPOLYGON (((0.12021 51.51144, 0.12054 51.5...
# 28  MULTIPOLYGON (((-0.09766 51.57365, -0.09756 51...
# 22  MULTIPOLYGON (((-0.24456 51.48870, -0.24460 51...
# 29  MULTIPOLYGON (((-0.09766 51.57365, -0.09780 51...
# 7   MULTIPOLYGON (((-0.40407 51.61318, -0.40320 51...
# 5   MULTIPOLYGON (((0.15869 51.51219, 0.15871 51.5...
# 6   MULTIPOLYGON (((-0.40407 51.61318, -0.40388 51...
# 3   MULTIPOLYGON (((-0.24456 51.48870, -0.24468 51...
# 27  MULTIPOLYGON (((-0.13839 51.55686, -0.13852 51...
# 23  MULTIPOLYGON (((-0.18388 51.47742, -0.18403 51...
# 0   MULTIPOLYGON (((-0.33068 51.32901, -0.33059 51...
# 10  MULTIPOLYGON (((-0.12846 51.48505, -0.12843 51...
# 12  MULTIPOLYGON (((-0.03241 51.49306, -0.03240 51...
# 20  MULTIPOLYGON (((-0.13432 51.39093, -0.13438 51...
# 30  MULTIPOLYGON (((-0.00786 51.52301, -0.00811 51...
# 17  MULTIPOLYGON (((0.06937 51.54413, 0.06910 51.5...
# 19  MULTIPOLYGON (((-0.32173 51.46541, -0.32172 51...
# 11  MULTIPOLYGON (((-0.10892 51.50844, -0.10889 51...
# 18  MULTIPOLYGON (((-0.15657 51.32151, -0.15866 51...
# 26  MULTIPOLYGON (((-0.07938 51.50784, -0.07935 51...
# 16  MULTIPOLYGON (((0.01924 51.60822, 0.01931 51.6...
# 21  MULTIPOLYGON (((-0.22343 51.47152, -0.22327 51...
# 24  MULTIPOLYGON (((-0.15000 51.48548, -0.15009 51...

# %%
totals_geo.to_file("london.geojson", driver='GeoJSON')
